# %%
from datetime import datetime

class Bank:
    pin=1234
    pincount=1
    acbal=10000
    wcount=0
    transactions=[]

    #selecting options
    def viewOptions(self):
        print("1. Deposit ")
        print("2. Withdarw ")
        print("3. Bal Enquiry ")
        print("4. Change pin")
        print("5. Transaction history")
        print("0. EXIT ")
        opt=int(input("Choose your option"))
        if opt==1:
            obj.deposit()
            obj.confirm()
        elif opt==2:
            if self.wcount<3:
                obj.withdraw()
                obj.confirm()
            else:
                print("Withdraw limit is over, please try after 24 hrs")
        elif opt==3:
            print("Available bal is : ",self.acbal)
            obj.confirm()
        elif opt==4:
            obj.change_pin()
            obj.confirm()
        elif opt==5:
            obj.transaction_history()
            obj.confirm()
        else:
            print("Thank yoy Visit again")


    #pin verification
    def validate(self):
        pin=int(input("Enter your pin : "))
        if self.pin==pin:
           obj.viewOptions()
        else:
            self.pincount+=1
            if self.pincount<=3:
                print("Invalid pin, please try again")
                obj.validate()
            else:
                print("Your card is blocked for the day")

    #amt deposit
    def deposit(self):
        amt=int(input("Enter deposit amount : "))
        if amt%100==0:
            if amt<=50000:
                self.acbal+=amt
                self.transactions.append(f"Deposited ₹{amt} on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
                print("Avaialble bal is : ",self.acbal)
            else:
                print("Transaction limit is 20000 only")

        else:
            print("Please enter multiples of 100 ")


    #transaction history
    def transaction_history(self):
        if self.transactions:
          print("Tansaction History:")
          for transactions in self.transactions:
            print(transactions)
        else:
           print("No transactions found.")


    #change pin (or) create new pin
    def change_pin(self):
        current_pin=int(input("Enter your current pin : "))
        if (current_pin==self.pin):
            new_pin=int(input("Enter your new pin :"))
            self.pin=new_pin
            print("your pin is changed Successfully")
            obj.confirm()
        else:
            print("Invalid pin")
            obj.confirm()

    #conformation to continue or exait
    def confirm(self):
        opt=int(input("1.Continue  \n 0. EXIT "))
        if opt==1:
                obj.viewOptions()
        else:
            print("Thank you, Visit again ")

    #withdrawl process
    def withdraw(self):
        amt=int(input("Enter withdraw amount : "))
        if amt%100==0:
            if amt<=self.acbal:
                if amt<=20000:
                    self.acbal-=amt
                    self.wcount+=1
                    self.transactions.append(f"Withdraw ₹{amt} on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
                    print("Avalilable bal is : ",self.acbal)

                else:
                    print("Transaction limit is 20000 only")
            else:
                print("insuffient fund ")
        else:
            print("Please enter multiples of 100 only")


obj=Bank()
obj.validate()
# Out:
# Enter your pin : 1234
# 1. Deposit
# 2. Withdarw
# 3. Bal Enquiry
# 4. Change pin
# 5. Transaction history
# 0. EXIT
# Choose your option1
# Enter deposit amount : 17000
# Avaialble bal is :  27000
# 1.Continue
#  0. EXIT 1
# 1. Deposit
# 2. Withdarw
# 3. Bal Enquiry
# 4. Change pin
# 5. Transaction history
# 0. EXIT
# Choose your option2
# Enter withdraw amount : 2000
# Avalilable bal is :  25000
# 1.Continue
#  0. EXIT 1
# 1. Deposit
# 2. Withdarw
# 3. Bal Enquiry
# 4. Change pin
# 5. Transaction history
# 0. EXIT
# Choose your option3
# Available bal is :  25000
# 1.Continue
#  0. EXIT 1
# 1. Deposit
# 2. Withdarw
# 3. Bal Enquiry
# 4. Change pin
# 5. Transaction history
# 0. EXIT
# Choose your option4
# Enter your current pin : 1234
# Enter your new pin :7766
# your pin is changed Successfully
# 1.Continue
#  0. EXIT 1
# 1. Deposit
# 2. Withdarw
# 3. Bal Enquiry
# 4. Change pin
# 5. Transaction history
# 0. EXIT
# Choose your option4
# Enter your current pin : 7766
# ...
